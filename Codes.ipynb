# %%
load_dotenv()

# %% [markdown]
# Reads the .env file

# %%
streamlit run main_pipeline_streamlit.py

# %% [markdown]
# Run pipeline

# %% [markdown]
# git checkout --orphan fresh-main: created a new branch with zero commit history (orphan = no parent commits, so all  old commits with secrets get left behind)
# git add . : staged all your current files
# git commit -m "Initial commit" : made one single clean commit with no secrets in it
# git push -u origin fresh-main:main --force : pushed that clean commit to GitHub's main branch, overwriting the old history
